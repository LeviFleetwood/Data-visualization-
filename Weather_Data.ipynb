# %% [markdown]
# This is me talking about weather

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
# Direct link format for Google Drive file
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vRB8UU2OOVGlQ09NMqpWGNOLZXOYf0gHuzi75sS6PfsseBm1Ov29QvrZnB5nZ-BqWUXJpHrJCo_x08j/pub?output=csv'
tempDataFull = pd.read_csv(url, index_col = 'City')

tempDataFull
# Out:
#          Region  Country  State  Month  Day  Year  AvgTemperature
# City
# Algiers  Africa  Algeria    NaN      1    1  1995            64.2
# Algiers  Africa  Algeria    NaN      1    2  1995            49.4
# Algiers  Africa  Algeria    NaN      1    3  1995            48.8
# Algiers  Africa  Algeria    NaN      1    4  1995            46.4
# Algiers  Africa  Algeria    NaN      1    5  1995            47.9
# ...         ...      ...    ...    ...  ...   ...             ...
# Algiers  Africa  Algeria    NaN     11   30  2014            63.4
# Algiers  Africa  Algeria    NaN     12    1  2014            57.9
# Algiers  Africa  Algeria    NaN     12    2  2014            57.3
# Algiers  Africa  Algeria    NaN     12    3  2014            58.0
# Algiers  Africa  Algeria    NaN     12    4  2014            55.6
#
# [7278 rows x 7 columns]

# %%
df1995 = tempDataFull.query('Year == 1995')
df1995avg = df1995['AvgTemperature'].mean()

# %%
df = tempDataFull.query('Month == 1 and Day == 2')

df
# Out:
#          Region  Country  State  Month  Day  Year  AvgTemperature
# City
# Algiers  Africa  Algeria    NaN      1    2  1995            49.4
# Algiers  Africa  Algeria    NaN      1    2  1996            60.0
# Algiers  Africa  Algeria    NaN      1    2  1997            59.0
# Algiers  Africa  Algeria    NaN      1    2  1998            52.5
# Algiers  Africa  Algeria    NaN      1    2  1999            49.4
# Algiers  Africa  Algeria    NaN      1    2  2000            46.5
# Algiers  Africa  Algeria    NaN      1    2  2001            53.5
# Algiers  Africa  Algeria    NaN      1    2  2002            59.0
# Algiers  Africa  Algeria    NaN      1    2  2003            54.4
# Algiers  Africa  Algeria    NaN      1    2  2004            54.9
# Algiers  Africa  Algeria    NaN      1    2  2005            46.7
# Algiers  Africa  Algeria    NaN      1    2  2006            47.0
# Algiers  Africa  Algeria    NaN      1    2  2007            51.0
# ...

# %%
px.line(df, x='Year', y='AvgTemperature')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df, x='Year', y='AvgTemperature', color='AvgTemperature')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = tempDataFull.query('Month == 1 and Year == 1995')

df
# Out:
#          Region  Country  State  Month  Day  Year  AvgTemperature
# City
# Algiers  Africa  Algeria    NaN      1    1  1995            64.2
# Algiers  Africa  Algeria    NaN      1    2  1995            49.4
# Algiers  Africa  Algeria    NaN      1    3  1995            48.8
# Algiers  Africa  Algeria    NaN      1    4  1995            46.4
# Algiers  Africa  Algeria    NaN      1    5  1995            47.9
# Algiers  Africa  Algeria    NaN      1    6  1995            48.7
# Algiers  Africa  Algeria    NaN      1    7  1995            48.9
# Algiers  Africa  Algeria    NaN      1    8  1995            49.1
# Algiers  Africa  Algeria    NaN      1    9  1995            49.0
# Algiers  Africa  Algeria    NaN      1   10  1995            51.9
# Algiers  Africa  Algeria    NaN      1   11  1995            51.7
# Algiers  Africa  Algeria    NaN      1   12  1995            51.3
# Algiers  Africa  Algeria    NaN      1   13  1995            47.0
# ...

# %%
avgThing = tempDataFull.query('Month == 1 and Year == 1995')

avgThing['AvgTemperature'].mean()
# Out:
# 51.41935483870969

# %% [markdown]
# Scatter chat for the Month of January showing the Avg Temperature per day in 1995.

# %%
px.scatter(df,x='Day',y='AvgTemperature', color='AvgTemperature',

           title ='Scatter chat for the Month of January showing the Avg Temperature per day in 1995.',
           size ='AvgTemperature')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = tempDataFull.query('Month == 1')

df
# Out:
#          Region  Country  State  Month  Day  Year  AvgTemperature
# City
# Algiers  Africa  Algeria    NaN      1    1  1995            64.2
# Algiers  Africa  Algeria    NaN      1    2  1995            49.4
# Algiers  Africa  Algeria    NaN      1    3  1995            48.8
# Algiers  Africa  Algeria    NaN      1    4  1995            46.4
# Algiers  Africa  Algeria    NaN      1    5  1995            47.9
# ...         ...      ...    ...    ...  ...   ...             ...
# Algiers  Africa  Algeria    NaN      1   27  2014            58.4
# Algiers  Africa  Algeria    NaN      1   28  2014            56.0
# Algiers  Africa  Algeria    NaN      1   29  2014            53.8
# Algiers  Africa  Algeria    NaN      1   30  2014            51.5
# Algiers  Africa  Algeria    NaN      1   31  2014            48.2
#
# [620 rows x 7 columns]

# %%
px.scatter(df,x='Year',y='AvgTemperature', color='AvgTemperature')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = tempDataFull.query('Month == 1 and Day == 1')
df
# Out:
#          Region  Country  State  Month  Day  Year  AvgTemperature
# City
# Algiers  Africa  Algeria    NaN      1    1  1995            64.2
# Algiers  Africa  Algeria    NaN      1    1  1996            67.4
# Algiers  Africa  Algeria    NaN      1    1  1997            57.7
# Algiers  Africa  Algeria    NaN      1    1  1998            50.9
# Algiers  Africa  Algeria    NaN      1    1  1999            52.6
# Algiers  Africa  Algeria    NaN      1    1  2000            43.9
# Algiers  Africa  Algeria    NaN      1    1  2001            46.6
# Algiers  Africa  Algeria    NaN      1    1  2002            54.7
# Algiers  Africa  Algeria    NaN      1    1  2003            54.6
# Algiers  Africa  Algeria    NaN      1    1  2004            50.8
# Algiers  Africa  Algeria    NaN      1    1  2005            50.3
# Algiers  Africa  Algeria    NaN      1    1  2006            52.2
# Algiers  Africa  Algeria    NaN      1    1  2007            50.5
# ...

# %%
px.scatter(df,y='AvgTemperature',title='Average temp of the same day from 1995-2014.',
                 size='AvgTemperature', color='AvgTemperature',)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
tempDataFull.groupby(["Month","Day"])["AvgTemperature"].agg(['mean','sum'])
# Out:
#                 mean     sum
# Month Day
# 1     1    53.140000  1062.8
#       2    52.700000  1054.0
#       3    53.205000  1064.1
#       4    51.515000  1030.3
#       5    51.275000  1025.5
# ...              ...     ...
# 12    27   52.315789   994.0
#       28   52.257895   992.9
#       29   52.884211  1004.8
#       30   45.094737   856.8
#       31   45.305263   860.8
#
# [366 rows x 2 columns]

# %%
px.scatter(df,y='AvgTemperature', x='Day', color='AvgTemperature', title='Average temp of every month from 1995-2014.',
           size='AvgTemperature')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country",
           log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])

fig["layout"].pop("updatemenus") # optional, drop animation buttons
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# https://plotly.com/python/sliders/

# %%
df = tempDataFull.groupby(['Month', "Day"], as_index=False)["AvgTemperature"].mean()
dfQueried = df.query('Month == 1')
# Write a program that allows the user to change the data query for the Month selection (1, 2, 3 etc.)

dfQueried
# Out:
#     Month  Day  AvgTemperature
# 0       1    1          53.140
# 1       1    2          52.700
# 2       1    3          53.205
# 3       1    4          51.515
# 4       1    5          51.275
# 5       1    6          51.670
# 6       1    7          50.750
# 7       1    8          50.505
# 8       1    9          51.060
# 9       1   10          43.645
# 10      1   11          51.185
# 11      1   12          51.415
# 12      1   13          43.785
# 13      1   14          51.175
# 14      1   15          51.650
# 15      1   16          51.005
# 16      1   17          51.300
# 17      1   18          51.195
# 18      1   19          52.340
# 19      1   20          53.430
# 20      1   21          51.940
# 21      1   22          51.925
# 22      1   23          52.405
# 23      1   24          52.480
# 24      1   25          51.035
# 25      1   26          50.005
# 26      1   27          52.340
# 27      1   28          53.485
# 28      1   29          52.185
# ...

# %%
fig = px.scatter(df, x="Day", y="AvgTemperature",
                 animation_frame="Month", size="AvgTemperature",
                 size_max=15, range_x=[-1, 35],range_y=[30, 85],
                 title="Average Temperature by Day from 1995-2014", color = 'AvgTemperature')
# range_y=[df['AvgTemperature'].min(), df['AvgTemperature'].max()]
fig["layout"].pop("updatemenus")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# dfQ = df.query('Year == 1')

# %%
df = tempDataFull.groupby(['Year','Month'], as_index=False)['AvgTemperature'].max()
dfQ = df.query('Month == 1')
dfQ
# Out:
#      Year  Month  AvgTemperature
# 0    1995      1            64.2
# 12   1996      1            67.4
# 24   1997      1            67.9
# 36   1998      1            61.1
# 48   1999      1            60.2
# 60   2000      1            54.0
# 72   2001      1            63.4
# 84   2002      1            59.0
# 96   2003      1            57.8
# 108  2004      1            59.4
# 120  2005      1            56.9
# 132  2006      1            58.2
# 144  2007      1            59.9
# 156  2008      1            59.1
# 168  2009      1            61.3
# 180  2010      1            59.8
# 192  2011      1            61.6
# 204  2012      1            54.7
# 216  2013      1            62.7
# 228  2014      1            60.7

# %%
fig = px.scatter(df, x='Month', y='AvgTemperature',
               animation_frame= 'Year', size='AvgTemperature',
               range_x=[-1, 13],range_y=[30, 100], color='AvgTemperature',
               title='Highest temperaature of each Month/Year 1995-2014')
fig ['layout'].pop('updatemenus')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = tempDataFull.groupby(['Day','Month'],as_index=False)['AvgTemperature'].min()
df
# Out:
#      Day  Month  AvgTemperature
# 0      1      1            43.9
# 1      1      2            37.8
# 2      1      3            43.7
# 3      1      4            47.4
# 4      1      5            52.3
# ..   ...    ...             ...
# 361   31      5            61.8
# 362   31      7            75.5
# 363   31      8            72.9
# 364   31     10            54.7
# 365   31     12           -99.0
#
# [366 rows x 3 columns]

# %%
valid_size_values = df['AvgTemperature'].loc[df['AvgTemperature'] >= 0]
valid_df = df.loc[df['AvgTemperature'] >= 0]
fig = px.scatter(valid_df, x='Month', y='AvgTemperature',
                 animation_frame='Day', size=valid_size_values,
                 range_x=[-1, 13], range_y=[30, 100], color='AvgTemperature',
                 title='Min temp for each day of each month from 1995-2014')
fig['layout'].pop('updatemenus')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
